# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pwd
# Out:
# /content

# %%
ROOT_DIR = '/content/gdrive/MyDrive/ANPR_YOLOv8'

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Ob3tQiP2G9Ijlp2mdfnm")
project = rf.workspace("pbl-tz4us").project("license_plate_dataset-w3vm8")
version = project.version(4)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.8/89.8 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 21.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 71.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 97.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to License_Plate_Dataset-4 in yolov8:: 100%|██████████| 610/610 [00:00<00:00, 10699.13it/s]

# %%
# !pip install --upgrade pip
# !pip install ultralytics --upgrade
# !pip install numpy==1.25.2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 79.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 52.4 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [ultralytics]
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 37.2 MB/s  0:00:00
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# ...

# %%
import os
from ultralytics import YOLO

# Load the model (YOLOv8 medium)
model = YOLO("yolov8m.yaml")

# Train the model from scratch (avoid checkpoint errors)
results = model.train(
    data='/content/dataset/data.yaml',
    epochs=100,
    project=ROOT_DIR,
    name="results",
    exist_ok=True,
    resume=False   # important
)

# %%
# !zip -r dataset.zip /content/dataset
# Out:
#   adding: content/dataset/ (stored 0%)
#   adding: content/dataset/README.dataset.txt (deflated 16%)
#   adding: content/dataset/train/ (stored 0%)
#   adding: content/dataset/train/labels/ (stored 0%)
#   adding: content/dataset/train/labels/Cars111_png.rf.94b96a75a4d195d563c95ad94218da36.txt (deflated 31%)
#   adding: content/dataset/train/labels/Cars277_png.rf.3ea14fe6141e06686ac9b9b87ee07cd4.txt (deflated 50%)
#   adding: content/dataset/train/labels/Cars199_png.rf.2379c2f10fe9c585e4df900e4bf659b9.txt (deflated 13%)
#   adding: content/dataset/train/labels/Cars139_png.rf.caaff9658b1c3312431239e914b405cd.txt (deflated 51%)
#   adding: content/dataset/train/labels/Cars246_png.rf.009232030935c09c1dc36f2932167a13.txt (deflated 29%)
#   adding: content/dataset/train/labels/Cars413_png.rf.efd990af61e5f8eb1e81247de08705d4.txt (deflated 30%)
#   adding: content/dataset/train/labels/Cars20_png.rf.54227e84abe81e60a16b2ffb660050e3.txt (deflated 21%)
# ...

# %%
from google.colab import files
files.download("/content/dataset.zip")
